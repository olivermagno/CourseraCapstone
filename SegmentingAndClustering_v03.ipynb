# %% [markdown]
# # Segmenting and Clustering Neighborhoods in New York City

# %% [markdown]
# ### Install Beautifulsoup Library

# %%
# !conda install -c anaconda beautifulsoup4
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py36_0         156 KB  anaconda
#     beautifulsoup4-4.8.2       |           py36_0         161 KB  anaconda
#     openssl-1.1.1              |       h7b6447c_0         5.0 MB  anaconda
#     ca-certificates-2019.11.27 |                0         132 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         5.5 MB
#
# The following packages will be UPDATED:
#
#     beautifulsoup4:  4.7.1-py36_1      --> 4.8.2-py36_0      anaconda
#     ca-certificates: 2019.11.27-0      --> 2019.11.27-0      anaconda
#     certifi:         2019.11.28-py36_0 --> 2019.11.28-py36_0 anaconda
#     openssl:         1.1.1d-h7b6447c_3 --> 1.1.1-h7b6447c_0  anaconda
#
#
# Downloading and Extracting Packages
# certifi-2019.11.28   | 156 KB    | ##################################### | 100%
# beautifulsoup4-4.8.2 | 161 KB    | ##################################### | 100%
# openssl-1.1.1        | 5.0 MB    | ##################################### | 100%
# ca-certificates-2019 | 132 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ### Import BeautifulSoup and Requests

# %%
from bs4 import BeautifulSoup
import requests
import lxml.html as lh

# %% [markdown]
# ### Parse the html page

# %%
html_path = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = requests.get(html_path)
doc = lh.fromstring(page.content)
html_page = page.text

tr_elements = doc.xpath('//tr')

# %% [markdown]
# ### Parse Table Header

# %%
col = []
i = 0
for t in tr_elements[0]:
    i += 1
    name = t.text_content().rstrip('\r\n') #strip the trailing new line
    print(name)
    print('%d: "%s"'%(i, name))
    col.append((name,[]))
# Out:
# Postcode
# 1: "Postcode"
# Borough
# 2: "Borough"
# Neighborhood
# 3: "Neighborhood"

# %% [markdown]
# ### Create Pandas DataFrame

# %%
for j in range(1,len(tr_elements)):
    
    T = tr_elements[j] #jth row
    
    if len(T) != 3: #check if it is the lenght of our header
        break
    
    i = 0 # index of the column
    
    for t in T.iterchildren(): #iterate to each element of the row
        data = t.text_content().rstrip('\r\n') #strip the trailing newline
        
        if i > 0: #check if row is empty
            try:
                data = int(data)
            except:
                pass
            
        col[i][1].append(data) #append data to the empty list of the i'th column
        i += 1

# %%
import pandas as pd
import numpy as np

dic = {title:column for (title, column) in col}
df =  pd.DataFrame(dic)
print(df.head())
print("\nDataFrame shape is: {}".format(df.shape))
# Out:
#   Postcode           Borough      Neighborhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
#
# DataFrame shape is: (287, 3)

# %% [markdown]
# #### Copy value of Borough to Neighborhood if Borough is != "Not assigned"

# %%
df.Neighborhood = np.where(df.Neighborhood == 'Not assigned', df.Borough, df.Neighborhood) 
df.head()
# Out:
#   Postcode           Borough      Neighborhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
df.drop(df[df['Neighborhood'] == 'Not assigned'].index)
df.reset_index(drop = True, inplace = True) #reset index
df.head(15)
# Out:
#    Postcode           Borough      Neighborhood
# 0       M1A      Not assigned      Not assigned
# 1       M2A      Not assigned      Not assigned
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M6A        North York  Lawrence Heights
# 6       M6A        North York    Lawrence Manor
# 7       M7A  Downtown Toronto      Queen's Park
# 8       M8A      Not assigned      Not assigned
# 9       M9A      Queen's Park      Queen's Park
# 10      M1B       Scarborough             Rouge
# 11      M1B       Scarborough           Malvern
# 12      M2B      Not assigned      Not assigned
# 13      M3B        North York   Don Mills North
# 14      M4B         East York  Woodbine Gardens

# %%
print("New DataFrame shape is: {}".format(df.shape))
# Out:
# New DataFrame shape is: (287, 3)

# %%
df.sort_values(by="Postcode")
df_new = df[df.Borough != 'Not assigned']
#df.reset_index(drop = True, inplace = True)
df_new.reset_index(drop = True,inplace = True)
df_new.head(10)
# Out:
#   Postcode           Borough      Neighborhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      
200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘geolocation.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2020-01-13 19:08:23 (264 MB/s) - ‘geolocation.csv’ saved [2891/2891]

# %%
df_geoloc = pd.read_csv('geolocation.csv')
df_geoloc = df_geoloc.rename(columns={"Postal Code":"Postcode"})
df_geoloc = df_geoloc.sort_values(by=['Postcode'])
df_geoloc.head(10)
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476
# 5      M1J  43.744734 -79.239476
# 6      M1K  43.727929 -79.262029
# 7      M1L  43.711112 -79.284577
# 8      M1M  43.716316 -79.239476
# 9      M1N  43.692657 -79.264848

# %%
df_merge = pd.merge(df_new, df_geoloc, on='Postcode')
df_merge.groupby(df_merge.Neighborhood)
df_merge.head(10)
# Out:
#   Postcode           Borough      Neighborhood   Latitude  Longitude
# 0      M3A        North York         Parkwoods  43.753259 -79.329656
# 1      M4A        North York  Victoria Village  43.725882 -79.315572
# 2      M5A  Downtown Toronto      Harbourfront  43.654260 -79.360636
# 3      M6A        North York  Lawrence Heights  43.718518 -79.464763
# 4      M6A        North York    Lawrence Manor  43.718518 -79.464763
# 5      M7A  Downtown Toronto      Queen's Park  43.662301 -79.389494
# 6      M9A      Queen's Park      Queen's Park  43.667856 -79.532242
# 7      M1B       Scarborough             Rouge  43.806686 -79.194353
# 8      M1B       Scarborough           Malvern  43.806686 -79.194353
# 9      M3B        North York   Don Mills North  43.745906 -79.352188

# %%
df_merge.Borough.unique()
# Out:
# array(['North York', 'Downtown Toronto', "Queen's Park", 'Scarborough',
#        'East York', 'Etobicoke', 'York', 'East Toronto', 'West Toronto',
#        'Central Toronto', 'Mississauga'], dtype=object)

# %%
df_toronto = df_merge[df_merge['Borough'].isin(['Downtown Toronto', 'East Toronto', 'West Toronto', 'Central Toronto'])]
#df_toronto.set_index("Postcode", drop = True, inplace = True)
df_toronto.reset_index(drop = True, inplace = True)
df_toronto.head(10)
# Out:
#   Postcode           Borough        Neighborhood   Latitude  Longitude
# 0      M5A  Downtown Toronto        Harbourfront  43.654260 -79.360636
# 1      M7A  Downtown Toronto        Queen's Park  43.662301 -79.389494
# 2      M5B  Downtown Toronto             Ryerson  43.657162 -79.378937
# 3      M5B  Downtown Toronto     Garden District  43.657162 -79.378937
# 4      M5C  Downtown Toronto      St. James Town  43.651494 -79.375418
# 5      M4E      East Toronto         The Beaches  43.676357 -79.293031
# 6      M5E  Downtown Toronto         Berczy Park  43.644771 -79.373306
# 7      M5G  Downtown Toronto  Central Bay Street  43.657952 -79.387383
# 8      M6G  Downtown Toronto            Christie  43.669542 -79.422564
# 9      M5H  Downtown Toronto            Adelaide  43.650571 -79.384568

# %% [markdown]
# ## Folium Map

# %%
# !conda install -c conda-forge folium

import folium
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     folium-0.10.1              |             py_0          59 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.10.1-py_0       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# folium-0.10.1        | 59 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
df_map = folium.Map(location=[43.651070,-79.347015], zoom_start=12)
df_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for lat,lng,borough,neighborhood in zip(df_toronto['Latitude'],df_toronto['Longitude'],df_toronto['Borough'],df_toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker([lat,lng],
                        radius = 5,
                        popup = label,
                        color = 'blue',
                        fill = True,
                        fill_color = '#3186cc',
                        fill_opacity = 0.75,
                        parse_html=False).add_to(df_map)
    
df_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### KMeans

# %%
k = 5
df_cluster = df_toronto.drop(['Postcode','Borough','Neighborhood'],1)
kmeans = KMeans(n_clusters = k, random_state = 0).fit(df_cluster)
kmeans.labels_
df_toronto.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
df_toronto
# Out:
#     Cluster Labels Postcode           Borough  \
# 0                4      M5A  Downtown Toronto
# 1                4      M7A  Downtown Toronto
# 2                4      M5B  Downtown Toronto
# 3                4      M5B  Downtown Toronto
# 4                4      M5C  Downtown Toronto
# 5                3      M4E      East Toronto
# 6                4      M5E  Downtown Toronto
# 7                4      M5G  Downtown Toronto
# 8                2      M6G  Downtown Toronto
# 9                4      M5H  Downtown Toronto
# 10               4      M5H  Downtown Toronto
# 11               4      M5H  Downtown Toronto
# 12               0      M6H      West Toronto
# 13               0      M6H      West Toronto
# 14               4      M5J  Downtown Toronto
# 15               4      M5J  Downtown Toronto
# 16               4      M5J  Downtown Toronto
# 17               1      M6J      West Toronto
# 18               1      M6J      West Toronto
# 19               3      M4K      East Toronto
# 20               3      M4K      East Toronto
# 21               4      M5K  Downtown Toronto
# 22               4      M5K  Downtown Toronto
# 23               1      M6K      West Toronto
# 24               1      M6K      West Toronto
# 25               1      M6K      West Toronto
# 26               3      M4L      East Toronto
# 27               3      M4L      East Toronto
# 28               4      M5L  Downtown Toronto
# 29               4      M5L  Downtown Toronto
# ..             ...      ...               ...
# 44               2      M4S   Central Toronto
# 45               4      M5S  Downtown Toronto
# 46               4      M5S  Downtown Toronto
# 47               0      M6S      West Toronto
# 48               0      M6S      West Toronto
# 49               2      M4T   Central Toronto
# 50               2      M4T   Central Toronto
# 51               4      M5T  Downtown Toronto
# 52               4      M5T  Downtown Toronto
# 53               4      M5T  Downtown Toronto
# 54               2      M4V   Central Toronto
# 55               2      M4V   Central Toronto
# 56               2      M4V   Central Toronto
# 57               2      M4V   Central Toronto
# 58               2      M4V   Central Toronto
# 59               1      M5V  Downtown Toronto
# 60               1      M5V  Downtown Toronto
# 61               1      M5V  Downtown Toronto
# 62               1      M5V  Downtown Toronto
# 63               1      M5V  Downtown Toronto
# 64               1      M5V  Downtown Toronto
# 65               1      M5V  Downtown Toronto
# 66               2      M4W  Downtown Toronto
# 67               4      M5W  Downtown Toronto
# 68               4      M4X  Downtown Toronto
# 69               4      M4X  Downtown Toronto
# 70               4      M5X  Downtown Toronto
# 71               4      M5X  Downtown Toronto
# 72               4      M4Y  Downtown Toronto
# 73               3      M7Y      East Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                                        Harbourfront  43.654260 -79.360636
# 1                                        Queen's Park  43.662301 -79.389494
# 2                                             Ryerson  43.657162 -79.378937
# 3                                     Garden District  43.657162 -79.378937
# 4                                      St. James Town  43.651494 -79.375418
# 5                                         The Beaches  43.676357 -79.293031
# 6                                         Berczy Park  43.644771 -79.373306
# 7                                  Central Bay Street  43.657952 -79.387383
# 8                                            Christie  43.669542 -79.422564
# 9                                            Adelaide  43.650571 -79.384568
# 10                                               King  43.650571 -79.384568
# 11                                           Richmond  43.650571 -79.384568
# 12                                 Dovercourt Village  43.669005 -79.442259
# 13                                           Dufferin  43.669005 -79.442259
# 14                                  Harbourfront East  43.640816 -79.381752
# 15                                    Toronto Islands  43.640816 -79.381752
# 16                                      Union Station  43.640816 -79.381752
# 17                                    Little Portugal  43.647927 -79.419750
# 18                                            Trinity  43.647927 -79.419750
# 19                                  The Danforth West  43.679557 -79.352188
# 20                                          Riverdale  43.679557 -79.352188
# 21                                    Design Exchange  43.647177 -79.381576
# 22                            Toronto Dominion Centre  43.647177 -79.381576
# 23                                           Brockton  43.636847 -79.428191
# 24                                   Exhibition Place  43.636847 -79.428191
# 25                                   Parkdale Village  43.636847 -79.428191
# 26                                   The Beaches West  43.668999 -79.315572
# 27                                       India Bazaar  43.668999 -79.315572
# 28                                     Commerce Court  43.648198 -79.379817
# 29                                     Victoria Hotel  43.648198 -79.379817
# ..                                                ...        ...        ...
# 44                                         Davisville  43.704324 -79.388790
# 45                                            Harbord  43.662696 -79.400049
# 46                              University of Toronto  43.662696 -79.400049
# 47                                          Runnymede  43.651571 -79.484450
# 48                                            Swansea  43.651571 -79.484450
# 49                                         Moore Park  43.689574 -79.383160
# 50                                    Summerhill East  43.689574 -79.383160
# 51                                          Chinatown  43.653206 -79.400049
# 52                                        Grange Park  43.653206 -79.400049
# 53                                  Kensington Market  43.653206 -79.400049
# 54                                          Deer Park  43.686412 -79.400049
# 55                                     Forest Hill SE  43.686412 -79.400049
# 56                                          Rathnelly  43.686412 -79.400049
# 57                                         South Hill  43.686412 -79.400049
# 58                                    Summerhill West  43.686412 -79.400049
# 59                                           CN Tower  43.628947 -79.394420
# 60                                      Bathurst Quay  43.628947 -79.394420
# 61                                     Island airport  43.628947 -79.394420
# 62                                  Harbourfront West  43.628947 -79.394420
# 63                                   King and Spadina  43.628947 -79.394420
# 64                                      Railway Lands  43.628947 -79.394420
# 65                                      South Niagara  43.628947 -79.394420
# 66                                           Rosedale  43.679563 -79.377529
# 67                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 68                                        Cabbagetown  43.667967 -79.367675
# 69                                     St. James Town  43.667967 -79.367675
# 70                               First Canadian Place  43.648429 -79.382280
# 71                                   Underground city  43.648429 -79.382280
# 72                               Church and Wellesley  43.665860 -79.383160
# 73  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
#
# [74 rows x 6 columns]

# %% [markdown]
# ### Cluster Map of Toronto

# %%
import numpy as np

df_map2 = folium.Map(location=[43.651070,-79.347015], zoom_start=12)

x = np.array(k)
y = [i + x + (i * x)**2 for i in range(k)]
color = cm.rainbow(np.linspace(0,1,len(y)))
new_color = [colors.rgb2hex(i) for i in color]

markers = []

for lat,lon, neighborhood, cluster in zip(df_toronto['Latitude'],df_toronto['Longitude'],df_toronto['Neighborhood'],df_toronto['Cluster Labels']):
    label = folium.Popup(' Cluster' + str(cluster), parse_html = True)
    folium.CircleMarker([lat,lon],
                        radius = 5,
                        popup = label,
                        color = new_color[cluster - 2],
                        fill = True,
                        fill_color = new_color[cluster - 2],
                        fill_opacity = 0.75).add_to(df_map2)
    
df_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
